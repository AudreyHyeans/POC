# %%
from scipy.fftpack import fft
import scipy as sci

import numpy as np
import matplotlib.pyplot as plt
import signal

# %%
#period
T =1
#step delta 
#delta_t = 1/(10*f)
#parameter N
N=10
#time domain where the function is define
t = np.linspace(-1.*T,1.*T,100)
#frequence domain where the function is define
f = np.arange(-N,N+1,1)/T
# width 
L = 1*T
M = len(t)

print(np.shape(t), np.shape(f))
def triangular(t):
        y= 1- (2*np.abs(t)) /T
        return(y)
"""
plt.figure()
plt.plot(t,triangular(t))  
plt.xlim(-0.4,0.4)
plt.ylim(0,1)
plt.show();
"""
# Out:
# (100,) (21,)
# '\nplt.figure()\nplt.plot(t,triangular(t))  \nplt.xlim(-0.4,0.4)\nplt.ylim(0,1)\nplt.show();\n'

# %%
#let's define coefficients Fourier series
#t1 = np.linspace(-2*np.pi,2*np.pi,100)
harmonic = 0
for i in range(-N,N):
    harmonic+= 0.5* (np.sinc(i/2)**2) * np.exp( (1j*2*np.pi*i*t)/T) 
#print(c_m)
#im = plt.imread("external-content.duckduckgo.com.jpeg")
#implot = plt.imshow(im)
"""
plt.plot(t,np.real(harmonic), '*', color='black')
plt.plot(t,np.imag(harmonic), '*', color='red')
plt.plot(t,triangular(t))
plt.show()
"""
# Out:
# "\nplt.plot(t,np.real(harmonic), '*', color='black')\nplt.plot(t,np.imag(harmonic), '*', color='red')\nplt.plot(t,triangular(t))\nplt.show()\n"

# %% [markdown]
# ### try for triangular function

# %%
#fft?
print('fft',fft(triangular(t),n=50))
print('harmonic',harmonic)
# Out:
# fft [-0.50505051 -0.j         -1.01010101+16.0550958j
#  -1.01010101 +7.99577282j -1.01010101 +5.29513493j
#  -1.01010101 +3.93408369j -1.01010101 +3.10877125j
#  -1.01010101 +2.55122393j -1.01010101 +2.14657391j
#  -1.01010101 +1.83736692j -1.01010101 +1.59166451j
#  -1.01010101 +1.39028477j -1.01010101 +1.22100237j
#  -1.01010101 +1.07564832j -1.01010101 +0.94854799j
#  -1.01010101 +0.83562823j -1.01010101 +0.73388134j
#  -1.01010101 +0.64102959j -1.01010101 +0.55530773j
#  -1.01010101 +0.47531746j -1.01010101 +0.39992728j
#  -1.01010101 +0.32820171j -1.01010101 +0.25934986j
#  -1.01010101 +0.19268707j -1.01010101 +0.12760543j
#  -1.01010101 +0.06355017j -1.01010101 -0.j
#  -1.01010101 -0.06355017j -1.01010101 -0.12760543j
#  -1.01010101 -0.19268707j -1.01010101 -0.25934986j
#  -1.01010101 -0.32820171j -1.01010101 -0.39992728j
#  -1.01010101 -0.47531746j -1.01010101 -0.55530773j
#  -1.01010101 -0.64102959j -1.01010101 -0.73388134j
#  -1.01010101 -0.83562823j -1.01010101 -0.94854799j
#   84.   84.5  85.   85.5  86.   86.5  87.   87.5  88.   88.5  89.   89.5
#   90.   90.5  91.   91.5  92.   92.5  93.   93.5  94.   94.5  95.   95.5
#   96.   96.5  97.   97.5  98.   98.5  99.   99.5 100.  100.5 101.  101.5
#  102.  102.5 103.  103.5 104.  104.5 105.  105.5 106.  106.5 107.  107.5
#  108.  108.5 109.  109.5 110.  110.5 111.  111.5 112.  112.5 113.  113.5
#  114.  114.5 115.  115.5 116.  116.5 117.  117.5 118.  118.5 119.  119.5
#  120.  120.5 121.  121.5 122.  122.5 123.  123.5 124.  124.5 125.  125.5
#  126.  126.5 127.  127.5]

# %%
#define the function cos
h = A*np.cos(2*np.pi* 1/T *t+phi)
plt.plot(h)
plt.show()

# %%
#calculate the dfft
H = fft(h)
plt.plot(np.real(H), 
        label = 'real part')
plt.plot(np.imag(H),
        label = 'imaginary part')
plt.legend()
plt.grid()
plt.show()

# %%
h_FT = H/Fs
plt.plot(h_FT)
plt.show()
# Out:
# /home/audreyhyeans/miniconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
H_shifted=  sci.fftshift(h)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-d028e0ddd404> in <module>
# ----> 1 H_shifted=  sci.fftshift(h)
#
# AttributeError: module 'scipy' has no attribute 'fftshift'

# %%
#comparison to theoretical expression
frequency = ( fc* Fs / N) - Fs/2
H = fft(h)

# %%
#define the function sin
sin = A*np.sin(2*np.pi* 1/T *t+phi)
plt.plot(sin)
plt.show()

# %%
#calculate the dfft
SIN = fft(sin)
plt.plot(np.imag(SIN),
        label = 'imaginary part')
plt.plot(np.real(SIN), 
        label = 'real part')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Gaussian function

# %%
Ng = 2**8
sigma = 1
Fsg = 4
tg = np.arange(-(Ng/2) +1,(Ng/2))*Fsg

# %%
for sigma in [4,8,10,12]:
    gauss = 1/(np.sqrt(2*np.pi)*sigma) * np.exp(-tg**2/(2*sigma**2))
    plt.plot(tg,gauss)
plt.show()

# %%
for sigma in [4,8,10,12]:
    gauss = 1/(np.sqrt(2*np.pi)*sigma) * np.exp(-tg**2/(2*sigma**2))
    GAUSS = fft(gauss)
    plt.plot(np.real(GAUSS))
    plt.plot(np.imag(GAUSS))
plt.show()

# %%
#cumulative phase
sigma = 1
gauss = 1/(np.sqrt(2*np.pi)*sigma) * np.exp(-tg**2/(2*sigma**2))
GAUSS = fft(gauss)
plt.figure()
plt.title('real and imaginary parts')
plt.plot(np.real(GAUSS),label = 'real part')
plt.plot(np.imag(GAUSS),label = 'imaginary part')
plt.xlim(-0.5,0.5)
plt.legend(loc=2)

# %%
angle =  np.angle(GAUSS)
phase = np.unwrap(angle)

plt.figure(figsize=(10,5))
plt.title('phase')
plt.plot(phase)

plt.show()
