# %% [markdown]
# #  TP N°1
# ___________________________________________________________________________
#
# ## Exercise 1 : The Explicit Euler Method
#
# > ### a)
# > Write a Python function myeuler.py to solve the following problem with the Explicit Euler scheme:
# >
# > (𝑦'(𝑡) = −𝑦(𝑡), 𝑡 > 0, 𝑦(0) = 1) (P)
# >
# > The outputs are: t (discrete time array) and y (approximate solution array).
# >
# > The RHS of the equation will be defined in a python function modexp.py that takes one value of time and one value of y and calculates the RHS term of the equation, here:
# > 𝑦'(𝑡) = 𝐹(𝑡, 𝑦(𝑡)) 𝑤𝑖𝑡h 𝐹(𝑡, 𝑦) = −𝑦
# >

# %%
########################################################################### 
# Fonction for the equation = dy/dt = a.y    with a = -1
############################################################################

def modexp(t,y):
    
    ...

    return dydt

# %%
############################################################################
# Integration of the equation : dy/dt = f(t,y)
# With the numerical method : Explicit Euler
# f : name of the RHS function
# tspan : array containing first and last time
# y0 : initial condition
# n : number of time steps
# expected solution t = [t0,t1,...,tn] and y = [y0,y1,...,yn]
############################################################################

def myeuler(f,tspan,y0,n):
    import numpy as np

    #Initializations

    ...

    #Loop with explicit Euler's method
    
    ...

    return t,y

# %% [markdown]
# > Write a python program exec_myeuler_modexp.py that solves the problem and plot the approximate solution, the exact solution and estimate the error as the maximum of the modulus of the difference between exact and approximate solution.
# >
# > Example of call to the function myeuler in exec_myeuler_modexp.py to calculate the approximate solution from t=0 to t=10 with n iterations:
# >
# > y0 = 1
# > n = 1000
# > tspan = np.array(\[0,10\])
# > \[t,y\] = myeuler(modexp,tspan,y0,n)
# >
# > Try several values of n and comment the results.
# >
# >### b)
# >
# > Verify the stability criteria of the Explicit Euler’s method for the problem (P).

# %%
# PROGRAM exec_myeuler_modexp.py

############################################################################
# Integration of the exponential equation : dy/dt = a.y
# Function of the model in modexp.py
# Numerical method : Explicit Euler with real arrays in myeuler.py
############################################################################

#!/usr/bin/env python

import numpy as np
from matplotlib import pyplot as plt
# Import local functions if not being using Jupyter
#from myeuler import myeuler
#from modexp import modexp

#Initializations

...

#Approximate solution y

...

#Exact Solution yex

...

#Error calculation
errormax = np.max(np.abs(yex-y))
print('Error = ',errormax)

#Plot

...

# %% [markdown]
# >### c)
# >
# > Write a program analyse_euler_modexp.py that plots the error in function of the value of the time
# step Dt for the problem (P). Comment the order of the explicit Euler scheme.

# %%
# PROGRAM analyse_euler_modexp.py

############################################################################
# Analyse of the error in function of time step for the
# Integration of the exponential equation : dy/dt = a.y  (here with a = -1)
# Function of the model in modexp.py
# Numerical method : Explicit Euler with real arrays in myeuler.py
############################################################################

#!/usr/bin/env python

import numpy as np
from matplotlib import pyplot as plt
# Import local functions
#from myeuler import myeuler
#from modexp import modexp

# dt varies between 10^-a to 10^-b
# then n varies between integer part of ((tspan[1]-tspan[0])/dt)

...

# %% [markdown]
# ## Exercise 2 : The oscillation equation
# >
# > Consider the oscillation equation: (𝑦'(𝑡) = 𝑖 𝜔 𝑦(𝑡),    𝑡 ∈ [0,100],    𝑦(0) = 1,    𝜔 = 2𝜋/10)
# >
# > ### a)
# >
# > Solve this equation by using explicit Euler scheme. Hint : as for exercise 1 you have to write a function for the oscillation equation model (modoscilo.py)  another function for the Euler integration that manages complex numbers, and a program exec_myeulercplx_modoscilo.py that calculates de solution and plots it.
# >
# > ### b)
# >
# > Plot real and imaginary part of the approximate solution in function of time and in the phase space (Re(y),Im(y)) and plot also the exact solution.
# >
# > ### c)
# >
# > Comment the observed amplification factor by studying the stability of the numerical scheme with the oscillation equation.
# >

# %%
# Same as myeuler but working with complex arrays

############################################################################
# Integration of the  equation : dy/dt = f(t,y)
# With the numerical method : Explicit Euler
# Same as myeuler1 but allowing complex arrays
############################################################################

def myeulercplx(f,tspan,y0,n):
    import numpy as np

    ...

    return t,y

# %%
############################################################################
# Fonction for the equation : dy/dt = iw.y
############################################################################
def modoscilo(t,y):

    ...
    
    return dydt

# %%
# PROGRAM exec_myeulercplx_modoscilo.py

############################################################################
# Integration of the oscillation equation : dy/dt = i.w.y
# Function of the model in modoscilo.py
# Numerical method : Explicit Euler with complex arrays in myeuler1cplx.py
############################################################################

#!/usr/bin/env python

import numpy as np
from matplotlib import pyplot as plt
# Import local functions
#from myeulercplx import myeulercplx
#from modoscilo import modoscilo

# Initializations :

...

#Approximate solution y

...


# Exact Solution

...

# Error calculation

...

# Figures

...

# %% [markdown]
# ## Exercise 3 : The implicit Euler scheme
# >
# > Write a new function myeuler_imp.py that calculates approximate solution of a general problem:
# >
# > (𝑦'(𝑡) = 𝐹(𝑡, 𝑦(𝑡)), 𝑡 > 0, 𝑦(0) = 𝜂)
# >
# > with the implicit Euler scheme.
# >
# > At each time step the implicit equation will be solved by using the Newton’s method. Test it with the exponential model (modexp.py).
# >
# > Comment the stability of this method with the exponential model.
# >
# > hint : to apply the Newton’s method you will need the function of the model (here: 𝐹(𝑡, 𝑦)) but also the first derivative of F with respect to y (one way to get it is to calculate by hand in simple cases and implement it in a python function - or in a second time to estimate numerically this first derivative).
# >

# %%
############################################################################
# First derivative of the RHS Fonction for the equation = dy/dt = a.y = F(t,y)
############################################################################

def modexpdx(t,y):

    ...
    
    return dydt

# %%
############################################################################
# Integration of the  equation : dy/dt = f(t,y)
# With the numerical method : Explicit Euler
############################################################################

def myeuler_imp(f,dfdx,tspan,y0,n):
    import numpy as np

    
    #Initializations

    ...

    #Loop with implicit Euler's method with Newton algorithm
    
    ...

    #print('Newton iterations = ',nbopmax)

    return t,y

# %%
# PROGRAM exec_myeuler_imp_modexp.py

############################################################################
# Integration of the exponential equation : dy/dt = a.y
# Function of the model in modexp.py
# Numerical method : Implicit Euler with real arrays in myeuler_imp.py
# by using a Newton algorythm at each time step.
############################################################################

#!/usr/bin/env python

import numpy as np
from matplotlib import pyplot as plt
# Import local functions
#from myeuler_imp import myeuler_imp
#from modexp import modexp
#from modexpdx import modexpdx

# Initializations :

...

#Approximate solution y

...


# Exact Solution

...

# Error calculation

...

# Figures

...
