# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.arange(-101,101,1)
y = np.arange(-101,101,1)
X,Y = np.meshgrid(x,y)
v_x = 2*X**2 *Y
v_y = -2*X*Y**2

fig, ax1 = plt.subplots(1)

ax1.streamplot(X,Y,v_x,v_y, cmap = 'plasma')
#ax1.imshow(X,Y,v_x,v_y)
plt.show()
