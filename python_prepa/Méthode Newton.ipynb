# %% [markdown]
# # Méthode de Newton

# %% [markdown]
# * Explication :

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
def Newton (x0,P,Pp,N):
    x=x0
    p=x0-P(x)/Pp(x)
    while abs(x-p)==10**(-4):
        x=p
        if Pp(x)==0:
            return(N)
        p=p-P(p)/Pp(p)
        M=M+1
        if M>N:
            return(p)
    return(x,M)   
    
def P(A,x):
    return(x**3-A*x**2+A*x-1)

def Pp(A,x):
    return(3*x**2-2*A*x+A)

# %%
x = np.linspace(-20,20,40)
plt.figure()
plt.plot(x,P(8,x))
plt.plot(x,Pp(8,x))
plt.grid()
plt.show()
